# %% [markdown]
# # 01 - Data Exploration

# %% [markdown]
# ## Step 1: Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data_path = '../data/raw/transactions.csv'

# %% [markdown]
# ## Step 2: Schema Inspection
# - Show shape, info, data types
# - Count nulls and unique values

# %%
# Placeholder for:
# df.shape
# df.info()
# df.isnull().sum()
# df.nunique()

# %% [markdown]
# ## Step 3: Descriptive Stats and Distribution
# - Numerical summaries
# - Value counts for categories

# %% [markdown]
# ## Step 4: Data Dictionary
#
# | Column Name       | Data Type | Description                      | Example Value     |
# |-------------------|-----------|----------------------------------|-------------------|
# | transaction_id    | int       | Unique identifier for transaction | 123456            |
# | amount            | float     | Transaction value in dollars      | 239.50            |
# | transaction_type  | string    | Type of financial operation       | "withdrawal"      |
# | is_fraud          | int       | 1 if flagged as fraud, else 0     | 0                 |

# %% [markdown]
# ## Step 5: Initial Observations
# - Notes about data quality, risk flag fields, volume of anomalies
